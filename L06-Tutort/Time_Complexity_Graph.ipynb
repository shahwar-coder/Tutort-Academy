# %% [markdown]
# # Time Complexity Notations (GRAPH)

# %% [markdown]
# ![Screenshot 2025-10-27 at 10.10.40 PM.png](data:image/png;base64,...)

# %%
"""
• O(1): Constant time, input size doesn’t affect performance.
• O(log n): Logarithmic time, grows very slowly.
• O(n): Linear time, increases directly with input size.
• O(n log n): Log-linear time, efficient divide-and-conquer algorithms.
• O(n^2): Quadratic time, common with nested loops.
• O(n^3): Cubic time, even heavier nested operations.
• O(2^n): Exponential time, explodes rapidly.
• O(n!): Factorial time, impractical for large input sizes.
"""
# Out:
# '\n• O(1): Constant time, input size doesn’t affect performance.\n• O(log n): Logarithmic time, grows very slowly.\n• O(n): Linear time, increases directly with input size.\n• O(n log n): Log-linear time, efficient divide-and-conquer algorithms.\n• O(n^2): Quadratic time, common with nested loops.\n• O(n^3): Cubic time, even heavier nested operations.\n• O(2^n): Exponential time, explodes rapidly.\n• O(n!): Factorial time, impractical for large input sizes.\n'
